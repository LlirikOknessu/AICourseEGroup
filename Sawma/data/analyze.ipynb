# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv(r"C:\Users\M.M\Desktop\Git\AICourseEGroup\Sawma\data\raw\life_expectancy_data.csv")

# %%
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2727     Zimbabwe  2004  Developing              44.3            723.0
# 2728     Zimbabwe  2003  Developing              44.5            715.0
# 2729     Zimbabwe  2002  Developing              44.8             73.0
# 2730     Zimbabwe  2001  Developing              45.3            686.0
# 2731     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.describe(include="all").T
# Out:
#                                   count unique         top  freq  \
# Country                            2732    191      Guinea    16
# Year                             2732.0    NaN         NaN   NaN
# Status                             2732      2  Developing  2271
# Life expectancy                  2724.0    NaN         NaN   NaN
# Adult Mortality                  2724.0    NaN         NaN   NaN
# infant deaths                    2732.0    NaN         NaN   NaN
# Alcohol                          2547.0    NaN         NaN   NaN
# percentage expenditure           2732.0    NaN         NaN   NaN
# Hepatitis B                      2207.0    NaN         NaN   NaN
# Measles                          2732.0    NaN         NaN   NaN
#  BMI                             2699.0    NaN         NaN   NaN
# under-five deaths                2732.0    NaN         NaN   NaN
# Polio                            2714.0    NaN         NaN   NaN
# ...

# %%
df.columns = df.columns.str.strip()

# %%
fig, ax = plt.subplots()
levels = df['Life expectancy'].unique()
counts = []
for level in levels:
    counts.append(df['Life expectancy'].loc[df['Life expectancy'] == level].count())
print(levels)
print(counts)
ax.bar(levels, counts)
plt.grid()
plt.show()
# Out:
# [65.  59.9 59.5 59.2 58.8 58.6 58.1 57.3 57.  56.7 56.2 55.3 54.8 77.8
#  77.5 77.2 76.9 76.6 76.2 76.1 75.9 74.2 73.5 73.  72.8 73.3 73.6 72.6
#  75.6 75.4 75.3 75.1 74.9 74.7 74.4 74.1 73.8 73.4 72.3 71.7 71.6 71.4
#  71.3 52.4 51.7 51.1 56.  51.  49.6 49.1 48.7 48.2 47.7 47.4 47.1 46.8
#  46.5 45.7 45.3 76.4 75.7 75.2 75.  74.8 74.6 74.  76.3 75.5 73.9 73.2
#  72.9 72.7 72.  82.7 82.5 82.3 82.  81.7 81.3 81.2 81.  86.  83.  79.9
#  79.5 81.5 81.4 81.1 88.  84.  79.8 79.4 79.3 78.8 78.7 78.6 78.1 72.5
#  72.2 71.9 71.1 78.  69.2 68.4 67.8 67.5 66.6 74.5 73.1 76.7 76.5 76.
#  75.8 71.8 71.  77.  69.9 69.5 69.1 68.6 68.2 67.3 66.8 66.3 65.8 65.3
#  73.7 70.  69.8 68.9 68.1 67.2 68.  87.  80.  78.9 78.3 77.6 69.4 69.6
#  69.  68.7 68.5 68.3 60.  59.7 59.3 59.1 58.7 58.4 57.6 57.1 56.8 56.5
#  56.1 55.8 55.6 55.5 55.4 67.9 67.4 67.  66.5 64.2 63.3 62.5 61.7 62.
#  69.3 66.2 65.7 65.1 64.5 63.9 62.6 77.4 76.8 63.4 62.2 61.1 57.5 56.9
# ...

# %%
selected_country = 'Lebanon'
country_data = df[df['Country'] == selected_country]
plt.figure(figsize=(10, 6))
plt.hist(country_data['Life expectancy'], bins=20, edgecolor='black')
plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')
plt.title(f'Histogram of Life Expectancy in {selected_country}')
plt.grid(True)
plt.show()

# %%
selected_country = 'Lebanon'
country_data = df[df['Country'] == selected_country]
plt.figure(figsize=(10, 6))
plt.plot(country_data['Year'], country_data['Life expectancy'], marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.title(f'Life Expectancy Over the Years in {selected_country}')
plt.grid(True)
plt.show()

# %%
# Group by 'Status' and calculate mean life expectancy
status_life_expectancy = df.groupby('Status')['Life expectancy'].mean()
print(status_life_expectancy)
# Out:
# Status
# Developed     79.183948
# Developing    67.070128
# Name: Life expectancy, dtype: float64

# %%
# Bar plot of mean life expectancy by status
plt.figure(figsize=(10, 6))
status_life_expectancy.plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Status')
plt.ylabel('Mean Life Expectancy')
plt.title('Mean Life Expectancy by Country Status')
plt.grid(True)
plt.show()

# %%
# Group by 'Year' and 'Status' and calculate mean life expectancy
yearly_status_life_expectancy = df.groupby(['Year', 'Status'])['Life expectancy'].mean().unstack()

# Line plot of life expectancy over the years by status
plt.figure(figsize=(12, 6))
yearly_status_life_expectancy.plot()
plt.xlabel('Year')
plt.ylabel('Mean Life Expectancy')
plt.title('Mean Life Expectancy Over the Years by Country Status')
plt.grid(True)
plt.legend(title='Status')
plt.show()

# %%
adult_mortality_summary = df['Adult Mortality'].describe()
print(adult_mortality_summary)
# Out:
# count    2724.000000
# mean      165.923642
# std       123.837567
# min         1.000000
# 25%        75.000000
# 50%       145.000000
# 75%       228.250000
# max       723.000000
# Name: Adult Mortality, dtype: float64

# %%
#Trends Over Time
# Group by 'Year' and 'Status' and calculate mean adult mortality
yearly_status_adult_mortality = df.groupby(['Year', 'Status'])['Adult Mortality'].mean().unstack()

# Line plot of adult mortality over the years by status
plt.figure(figsize=(12, 6))
yearly_status_adult_mortality.plot()
plt.xlabel('Year')
plt.ylabel('Mean Adult Mortality')
plt.title('Mean Adult Mortality Over the Years by Country Status')
plt.grid(True)
plt.legend(title='Status')
plt.show()

# %%
# Group by 'Year' and calculate mean adult mortality and infant deaths rates
yearly_mortality = df.groupby('Year').agg({'Adult Mortality': 'mean', 'infant deaths': 'mean'})

# Plotting
plt.figure(figsize=(12, 6))

# Plotting adult mortality
plt.plot(yearly_mortality.index, yearly_mortality['Adult Mortality'], label='Adult Mortality', color='blue')

# Plotting infant mortality
plt.plot(yearly_mortality.index, yearly_mortality['infant deaths'], label='Infant Mortality', color='red')

plt.xlabel('Year')
plt.ylabel('Mean Mortality Rate')
plt.title('Comparison of Adult and Infant Mortality Rates Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
 #It's not uncommon for adult mortality rates to be higher than infant mortality rates in many populations. There are several reasons for this:
#-Population Age Structure
#-Disease Burden
#-Access to Healthcare
#-Public Health Interventions

# %%
# Histogram of alcohol consumption
plt.figure(figsize=(8, 6))
plt.hist(df['Alcohol'].dropna(), bins=30, edgecolor='black')
plt.xlabel('Alcohol Consumption (Liters)')
plt.ylabel('Frequency')
plt.title('Distribution of Alcohol Consumption')
plt.grid(True)
plt.show()

# %%
# Selecting countries of interest
countries_of_interest = ['Lebanon', 'France', 'United States of America', 'China', 'Russian Federation']

# Filter data for selected countries
selected_countries_data = df[df['Country'].isin(countries_of_interest)]

# Plotting scatter plot of alcohol consumption vs. life expectancy
plt.figure(figsize=(10, 6))
for country in countries_of_interest:
    country_data = selected_countries_data[selected_countries_data['Country'] == country]
    plt.scatter(country_data['Alcohol'], country_data['Life expectancy'], label=country)

plt.xlabel('Alcohol Consumption (Liters)')
plt.ylabel('Life Expectancy')
plt.title('Alcohol Consumption vs. Life Expectancy')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Selecting countries of interest
countries_of_interest = ['Lebanon', 'France', 'United States of America', 'China', 'Russian Federation']

# Filter data for selected countries
selected_countries_data = df[df['Country'].isin(countries_of_interest)]

# Plotting scatter plot of Hepatitis B vaccination coverage vs. life expectancy
plt.figure(figsize=(10, 6))
for country in countries_of_interest:
    country_data = selected_countries_data[selected_countries_data['Country'] == country]
    plt.scatter(country_data['Hepatitis B'], country_data['Life expectancy'], label=country)

plt.xlabel('Hepatitis B Vaccination Coverage (%)')
plt.ylabel('Life Expectancy')
plt.title('Hepatitis B Vaccination Coverage vs. Life Expectancy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Filter data for GDP per capita and life expectancy
gdp_life_data = df[['GDP', 'Life expectancy']]

# Plotting scatter plot of GDP per capita vs. life expectancy
plt.figure(figsize=(10, 6))
plt.scatter(gdp_life_data['GDP'], gdp_life_data['Life expectancy'], alpha=0.5)
plt.xlabel('GDP per Capita (USD)')
plt.ylabel('Life Expectancy')
plt.title('Relationship between GDP per Capita and Life Expectancy')
plt.grid(True)
plt.show()

# %%
#I dont think that the population is accurate!!!

# %%
# Set up the figure and axes
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot life expectancy against each variable
axs[0, 0].scatter(df['Measles'], df['Life expectancy'], color='skyblue', edgecolor='black')
axs[0, 0].set_title('Life Expectancy vs Measles')
axs[0, 0].set_xlabel('Measles Cases')
axs[0, 0].set_ylabel('Life Expectancy')

axs[0, 1].scatter(df['Polio'], df['Life expectancy'], color='lightgreen', edgecolor='black')
axs[0, 1].set_title('Life Expectancy vs Polio')
axs[0, 1].set_xlabel('Polio Immunization Rate (%)')
axs[0, 1].set_ylabel('Life Expectancy')

axs[1, 0].scatter(df['Diphtheria'], df['Life expectancy'], color='salmon', edgecolor='black')
axs[1, 0].set_title('Life Expectancy vs Diphtheria')
axs[1, 0].set_xlabel('Diphtheria Immunization Rate (%)')
axs[1, 0].set_ylabel('Life Expectancy')

axs[1, 1].scatter(df['HIV/AIDS'], df['Life expectancy'], color='gold', edgecolor='black')
axs[1, 1].set_title('Life Expectancy vs HIV/AIDS')
axs[1, 1].set_xlabel('HIV/AIDS Prevalence Rate')
axs[1, 1].set_ylabel('Life Expectancy')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Scatter plot for Total Expenditure
plt.figure(figsize=(10, 6))
plt.scatter(df['Total expenditure'], df['Life expectancy'])
plt.title('Total Expenditure vs. Life Expectancy')
plt.xlabel('Total Expenditure (% of GDP)')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# Scatter plot for Percentage Expenditure
plt.figure(figsize=(10, 6))
plt.scatter(df['percentage expenditure'], df['Life expectancy'])
plt.title('Percentage Expenditure vs. Life Expectancy')
plt.xlabel('Percentage Expenditure (% of GDP per capita)')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter the dataset for Lebanon
lebanon_data = df[df['Country'] == 'Lebanon']

# Group the data by year and calculate the mean total expenditure and life expectancy for each year
yearly_data = lebanon_data.groupby('Year').agg({'Total expenditure': 'mean', 'Life expectancy': 'mean'}).reset_index()

# Plot Total Expenditure vs. Life Expectancy for each year
plt.figure(figsize=(10, 6))
plt.plot(yearly_data['Year'], yearly_data['Total expenditure'], marker='o', label='Total Expenditure')
plt.plot(yearly_data['Year'], yearly_data['Life expectancy'], marker='o', label='Life Expectancy')
plt.title('Total Expenditure and Life Expectancy Over the Years in Lebanon')
plt.xlabel('Year')
plt.ylabel('Total Expenditure (% of GDP) / Life Expectancy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Filter the dataset for Lebanon
lebanon_data = df[df['Country'] == 'Lebanon']

# Group the data by year and calculate the mean percentage expenditure and life expectancy for each year
yearly_data = lebanon_data.groupby('Year').agg({'percentage expenditure': 'mean', 'Life expectancy': 'mean'}).reset_index()

# Plot Percentage Expenditure vs. Life Expectancy for each year
plt.figure(figsize=(10, 6))
plt.plot(yearly_data['Year'], yearly_data['percentage expenditure'], marker='o', label='Percentage Expenditure')
plt.plot(yearly_data['Year'], yearly_data['Life expectancy'], marker='o', label='Life Expectancy')
plt.title('Percentage Expenditure and Life Expectancy Over the Years in Lebanon')
plt.xlabel('Year')
plt.ylabel('Percentage Expenditure / Life Expectancy')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
thinness_1_19_years = df['thinness  1-19 years']
thinness_5_9_years = df['thinness 5-9 years']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Calculate correlation coefficient
correlation = df['Adult Mortality'].corr(df['Life expectancy'])

# Visualize the relationship with a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Adult Mortality'], df['Life expectancy'], alpha=0.5)
plt.title('Scatter Plot: Adult Mortality vs Life Expectancy')
plt.xlabel('Adult Mortality')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: -0.6968998741316409

# %%
# Plotting scatter plot for Thinness 1-19 years vs Life Expectancy
plt.figure(figsize=(10, 6))
plt.scatter(df['thinness  1-19 years'], df['Life expectancy'], color='skyblue', alpha=0.5)
plt.title('Life Expectancy vs Thinness 1-19 years')
plt.xlabel('Thinness 1-19 years')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# Plotting scatter plot for Thinness 5-9 years vs Life Expectancy
plt.figure(figsize=(10, 6))
plt.scatter(df['thinness 5-9 years'], df['Life expectancy'], color='salmon', alpha=0.5)
plt.title('Life Expectancy vs Thinness 5-9 years')
plt.xlabel('Thinness 5-9 years')
plt.ylabel('Life Expectancy')
plt.grid(True)
plt.show()

# %%
df = pd.read_csv(r'C:\Users\M.M\Desktop\Git\AICourseEGroup\Sawma\data\raw\life_expectancy_data.csv')

# Check for total null values
total_null_values = df.isnull().sum()

# Display the total null values for each column
print("Total null values for each column:\n", total_null_values)
# Out:
# Total null values for each column:
#  Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      8
# Adult Mortality                      8
# infant deaths                        0
# Alcohol                            185
# percentage expenditure               0
# Hepatitis B                        525
# Measles                              0
#  BMI                                33
# under-five deaths                    0
# Polio                               18
# Total expenditure                  215
# Diphtheria                          18
#  HIV/AIDS                            0
# GDP                                415
# Population                         604
#  thinness  1-19 years               33
#  thinness 5-9 years                 33
# Income composition of resources    155
# Schooling                          151
# dtype: int64

# %%
# Step 1: Identify all columns that contain numeric values
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Step 2: Calculate the mean for each numeric column
mean_values = df[numeric_columns].mean()

# Step 3: Fill null values in each numeric column with its respective mean
df[numeric_columns] = df[numeric_columns].fillna(mean_values)

# %%
# Check for total null values again
total_null_values = df.isnull().sum()
print("Total null values for each column after filling:\n", total_null_values)
# Out:
# Total null values for each column after filling:
#  Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
print(df.dtypes)
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

def encode_country_label(df):
    label_encoder = LabelEncoder()
    df['Country_Label'] = label_encoder.fit_transform(df['Country'])
    return df

# %%
df1=encode_country_label(df)

# %%
df1.drop(columns=['Country'], inplace=True)

# %%
df1
# Out:
#       Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0     2015  Developing              65.0            263.0             62
# 1     2014  Developing              59.9            271.0             64
# 2     2013  Developing              59.9            268.0             66
# 3     2012  Developing              59.5            272.0             69
# 4     2011  Developing              59.2            275.0             71
# ...    ...         ...               ...              ...            ...
# 2727  2004  Developing              44.3            723.0             27
# 2728  2003  Developing              44.5            715.0             26
# 2729  2002  Developing              44.8             73.0             25
# 2730  2001  Developing              45.3            686.0             25
# 2731  2000  Developing              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %%
def encode_status_label(df):
    label_encoder = LabelEncoder()
    df['Status'] = label_encoder.fit_transform(df['Status'])
    return df

# %%
df2=encode_status_label(df1)

# %%
df2
# Out:
#       Year  Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0     2015       1              65.0            263.0             62     0.01
# 1     2014       1              59.9            271.0             64     0.01
# 2     2013       1              59.9            268.0             66     0.01
# 3     2012       1              59.5            272.0             69     0.01
# 4     2011       1              59.2            275.0             71     0.01
# ...    ...     ...               ...              ...            ...      ...
# 2727  2004       1              44.3            723.0             27     4.36
# 2728  2003       1              44.5            715.0             26     4.06
# 2729  2002       1              44.8             73.0             25     4.43
# 2730  2001       1              45.3            686.0             25     1.72
# 2731  2000       1              46.0            665.0             24     1.68
#
# ...

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
y = df2['Life expectancy ']
X = df2.drop(columns=['Life expectancy '])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=1)

# %%
regr=linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted=regr.predict( X_test)

# %%
# Sample data
values = predicted

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(values, linestyle='-', color='b', label='Values')
plt.title('Plot of Values')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_test.reset_index(drop=True, inplace=True)

# %%
# Sample data
values = y_test

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(values, color='b', label='Values')
plt.title('Plot of Values')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Sample data
values = (y_test-predicted)

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(values, color='b', label='Values')
plt.title('Plot of Values')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Assuming y_test and predicted are numpy arrays
# If they are pandas Series, convert them to numpy arrays using .values
# Ensure they have compatible shapes
y_test = y_test.values.squeeze() if hasattr(y_test, 'values') else np.squeeze(y_test)
predicted = predicted.squeeze() if hasattr(predicted, 'values') else np.squeeze(predicted)

# Plotting the values
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Actual Values', color='b')
plt.plot(predicted, label='Predicted Values', color='r', alpha=0.7)
plt.xlabel('Sample Index')
plt.ylabel('Values')
plt.title('Actual vs Predicted Values')
plt.legend()
plt.show()

# %%
#plot the diference

# %%
from sklearn.metrics import r2_score

# Sample data
y_true = y_test
y_pred = predicted

# Calculate R-squared
r_squared = r2_score(y_true, y_pred)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.8108442706761879

# %%
import numpy as np

# Sample data
y_true = y_test
y_pred = predicted

# Calculate MSE
mse = np.mean((y_true - y_pred) ** 2)

# Calculate RMSE
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 4.195101551136915

# %% [markdown]
# ONLY THREE VARIAVBLES

# %%
X1 = df2[['Adult Mortality', 'Income composition of resources', 'Schooling']]

# %%
regr=linear_model.LinearRegression()
regr.fit(X1, y)
# Out:
# LinearRegression()

# %%
predicted=regr.predict(X1)

# %%
from sklearn.metrics import r2_score

# Sample data
y_true = y
y_pred = predicted

# Calculate R-squared
r_squared = r2_score(y_true, y_pred)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.7104528215116851

# %%
print(regr.coef_)
# Out:
# [-0.03459414 10.05327415  0.99726051]

# %%
import numpy as np

# Sample data
y_true = y
y_pred = predicted

# Calculate MSE
mse = np.mean((y_true - y_pred) ** 2)

# Calculate RMSE
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 5.109563563681676

# %%
# Select columns with float or integer data types
continuous_features = df.select_dtypes(include=['float64', 'int64'])

# Print the names of continuous features
print("Continuous Features:")
print(continuous_features.columns)
# Out:
# Continuous Features:
# Index(['Year', 'Life expectancy ', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=1)

# %%
# Load dependencies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
predictions = regr.predict(X_test)

# %%
import numpy as np

# Sample data
y_true = y_test
y_pred = predictions

# Calculate MSE
mse = np.mean((y_true - y_pred) ** 2)

# Calculate RMSE
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 4.054076030225652

# %% [markdown]
# MLP

# %%
# Load dependencies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X.shape
# Out:
# (2732, 15)

# %%
# Load data


# Set the input shape
input_shape = (15,)
print(f'Feature shape: {input_shape}')

# Create the model
model = Sequential()
model.add(Dense(64, input_shape=input_shape, activation='relu'))
model.add(Dense(32,  activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear'))

# Configure the model and start training
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_squared_error'])
h = model.fit(X, y, epochs=300, batch_size=8, verbose=1, validation_split=0.2)
# Out:
# Feature shape: (15,)
# Epoch 1/300
# C:\Users\M.M\Desktop\Git\AICourseEGroup\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 83.6733 - mean_squared_error: 92849.6328 - val_loss: 13.3847 - val_mean_squared_error: 416.7002
# Epoch 2/300
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18.3376 - mean_squared_error: 866.3687 - val_loss: 15.5453 - val_mean_squared_error: 602.3719
# Epoch 3/300
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 15.4025 - mean_squared_error: 752.4146 - val_loss: 9.6115 - val_mean_squared_error: 174.8852
# Epoch 4/300
# ...

# %%
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])

# %%
predictions = model.predict(X_test)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
predictions = np.squeeze(predictions)

# %%
predictions.shape
# Out:
# (547,)

# %%
y_test.shape
# Out:
# (547,)

# %%
import numpy as np

# Sample data
y_true = y_test
y_pred = predictions

# Calculate MSE
mse = np.mean((y_true - y_pred) ** 2)

# Calculate RMSE
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 3.07896038034751

# %%
from sklearn.metrics import r2_score


# Calculate R-squared
r_squared = r2_score(y_true, y_pred)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.8981073764801176

# %%
#PLOT THE REAL AND PREDICTED VALUES AND THE DIFFERENCE

# %%
y_true.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[693], line 1
# ----> 1 y_true.reset_index(drop=True, inplace=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'reset_index'

# %%
# Sample data
values = y_true

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(values, linestyle='-', color='b', label='Values')
plt.title('Plot of Values')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Sample data
values = y_pred

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(values, linestyle='-', color='b', label='Values')
plt.title('Plot of Values')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (2185, 15)
# y_train shape: (2185,)
# X_test shape: (547, 15)
# y_test shape: (547,)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import TensorBoard
import datetime

# Assuming X and y are already defined
# X_train, X_test, y_train, y_test are your train and test datasets

# Set the input shape
input_shape = (15,)
print(f'Feature shape: {input_shape}')

# Create the model
model = Sequential()
model.add(Dense(64, input_shape=input_shape, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear'))

# Configure the model
model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_squared_error'])

# Define the TensorBoard callback
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train the model with the TensorBoard callback
h = model.fit(X_train, y_train, epochs=300, batch_size=8, verbose=1, validation_data=(X_test, y_test), callbacks=[tensorboard_callback])

# To visualize the TensorBoard logs, you can start the TensorBoard server
# %tensorboard --logdir logs/fit
# Out:
# Feature shape: (15,)
# C:\Users\M.M\Desktop\Git\AICourseEGroup\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 61.1646 - mean_squared_error: 21872.2285 - val_loss: 31.5495 - val_mean_squared_error: 1492.0973
# Epoch 2/300
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.0625 - mean_squared_error: 823.2960 - val_loss: 18.4141 - val_mean_squared_error: 795.4449
# Epoch 3/300
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.8079 - mean_squared_error: 481.2050 - val_loss: 9.7000 - val_mean_squared_error: 184.0671
# Epoch 4/300
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 13032), started 5 days, 0:36:58 ago. (Use '!kill 13032' to kill it.)
#       <iframe id="tensorboard-frame-bde9a14446e23e37" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bde9a14446e23e37");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
print(df.columns)
# Out:
# Index(['Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Country_Label'],
#       dtype='object')

# %%
df1.drop(columns=['Population'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[625], line 1
# ----> 1 df1.drop(columns=['Population'], inplace=True)
#
# File ~\Desktop\Git\AICourseEGroup\venv\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
# ...

# %%
df1.drop(columns=['Year'], inplace=True)

# %%
df1.drop(columns=['Hepatitis B'], inplace=True)

# %%
df1.drop(columns=['Total expenditure'], inplace=True)

# %%
df1.drop(columns=['infant deaths'], inplace=True)

# %%
df1.drop(columns=['Measles '], inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
from IPython.display import Image
import graphviz

# Load the DOT file and display it
with open("dvc_graph.dot") as f:
    dot_graph = f.read()

# Render the DOT file as an image
graphviz.Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[703], line 5
#       2 import graphviz
#       4 # Load the DOT file and display it
# ----> 5 with open("dvc_graph.dot") as f:
#       6     dot_graph = f.read()
#       8 # Render the DOT file as an image
#
# File ~\Desktop\Git\AICourseEGroup\venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dvc_graph.dot'
